# %% [markdown]
# # Data Types and Structures Assignment Solutions

# %% [markdown]
# ## 1. What are data structures, and why are they important?
#
# **Answer:** Data structures are ways to organize and store data efficiently. They improve performance, simplify programming, and optimize memory usage.

# %% [markdown]
# ## 2. Explain the difference between mutable and immutable data types with examples.
#
# **Answer:** Mutable objects can be changed after creation (list, dict, set). Immutable objects cannot (int, str, tuple). Example: `lst=[1]; lst.append(2)` changes the list, while `s='hi'; s+='!'` creates a new string.

# %% [markdown]
# ### Create a string with your name and print it

# %%
name='Dhruv Bansal'
print(name)

# %% [markdown]
# ### Find length of 'Hello World'

# %%
text='Hello World'
print(len(text))

# %% [markdown]
# ### Slice first 3 chars

# %%
text='Python Programming'
print(text[:3])

# %% [markdown]
# ### Uppercase

# %%
print('hello'.upper())

# %% [markdown]
# ### Replace apple

# %%
print('I like apple'.replace('apple','orange'))

# %% [markdown]
# ### Create list 1-5

# %%
nums=[1,2,3,4,5]
print(nums)

# %% [markdown]
# ### Append 10

# %%
lst=[1,2,3,4]
lst.append(10)
print(lst)

# %% [markdown]
# ### Remove 3

# %%
lst=[1,2,3,4,5]
lst.remove(3)
print(lst)

# %% [markdown]
# ### Access second element

# %%
lst=['a','b','c','d']
print(lst[1])

# %% [markdown]
# ### Reverse list

# %%
lst=[10,20,30,40,50]
print(lst[::-1])

# %% [markdown]
# ### Tuple

# %%
t=(100,200,300)
print(t)

# %% [markdown]
# ### Second last tuple element

# %%
t=('red','green','blue','yellow')
print(t[-2])

# %% [markdown]
# ### Minimum tuple

# %%
print(min((10,20,5,15)))

# %% [markdown]
# ### Index cat

# %%
print(('dog','cat','rabbit').index('cat'))

# %% [markdown]
# ### Check kiwi

# %%
fruits=('apple','banana','mango')
print('kiwi' in fruits)

# %% [markdown]
# ### Create set

# %%
s={'a','b','c'}
print(s)

# %% [markdown]
# ### Clear set

# %%
s={1,2,3,4,5}
s.clear();print(s)

# %% [markdown]
# ### Remove 4

# %%
s={1,2,3,4}
s.remove(4);print(s)

# %% [markdown]
# ### Union

# %%
print({1,2,3}|{3,4,5})

# %% [markdown]
# ### Intersection

# %%
print({1,2,3}&{2,3,4})

# %% [markdown]
# ### Dictionary

# %%
d={'name':'John','age':25,'city':'NY'}
print(d)

# %% [markdown]
# ### Add country

# %%
d={'name':'John','age':25};d['country']='USA';print(d)

# %% [markdown]
# ### Access name

# %%
d={'name':'Alice','age':30};print(d['name'])

# %% [markdown]
# ### Remove age

# %%
d={'name':'Bob','age':22,'city':'New York'};d.pop('age');print(d)

# %% [markdown]
# ### Check city

# %%
d={'name':'Alice','city':'Paris'};print('city' in d)

# %% [markdown]
# ### Create list tuple dict

# %%
print([1,2],(1,2),{'a':1})

# %% [markdown]
# ### Random sorted

# %%
import random
l=[random.randint(1,100) for _ in range(5)]
print(sorted(l))

# %% [markdown]
# ### Third index

# %%
l=['a','b','c','d','e']
print(l[3])

# %% [markdown]
# ### Combine dicts

# %%
d1={'a':1};d2={'b':2};print(d1|d2)

# %% [markdown]
# ### List to set

# %%
print(set(['a','b','a','c']))
